# %%
import pandas as pd

# %%
animals = pd.read_csv("Resources/CombinedMammalsBirds.csv")
animals
# Out:
#       Code                     Place_Name Category  Sort     OrderName  \
# 0     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 1     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 2     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 3     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 4     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# ...    ...                            ...      ...   ...           ...
# 4899  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4900  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4901  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4902  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4903  YOSE         Yosemite National Park     Bird     2    Suliformes
#
#              FamilyName   Taxon       TSN TaxonRecordStatus  \
# ...

# %%
parks = pd.read_csv('Resources/parkLocations.csv')

# %%
parks
# Out:
#    Code                               Place_Name   Latitude   Longitude
# 0   ROMO            Rocky Mountain National Park  40.343182 -105.688103
# 1   KATM       Katmai National Park and Preserve  58.597813 -154.693756
# 2   GLBA  Glacier Bay National Park and Preserve  58.665806 -136.900208
# 3   CHIS           Channel Islands National Park  33.998028 -119.772949
# 4   DENA       Denali National Park and Preserve  63.129887 -151.197418
# 5   MORA             Mount Rainier National Park  46.879967 -121.726906
# 6   GRSM     Great Smoky Mountains National Park  35.611763  -83.489548
# 7   YOSE                  Yosemite National Park  37.865101 -119.538330
# 8   SHEN                Shenandoah National Park  38.700516  -78.292694
# 9   EVER                Everglades National Park  25.286615  -80.898651
# 10  YELL               Yellowstone National Park  44.423691 -110.588516
# 11  OLYM                   Olympic National Park  47.802109 -123.604355
# ...

# %%
animalLocations = pd.merge(animals, parks, how="left", on= "Place_Name")
animalLocations
# Out:
#       Code                     Place_Name Category  Sort     OrderName  \
# 0     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 1     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 2     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 3     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# 4     CHIS  Channel Islands National Park   Mammal     1     Carnivora
# ...    ...                            ...      ...   ...           ...
# 4899  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4900  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4901  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4902  YOSE         Yosemite National Park     Bird     2  Strigiformes
# 4903  YOSE         Yosemite National Park     Bird     2    Suliformes
#
#              FamilyName   Taxon       TSN TaxonRecordStatus  \
# ...

# %%
animalLocations.to_csv('Resources/AnimalLocations.csv', index=False)
